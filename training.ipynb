# %%
import pandas as pd

dh_train = pd.read_excel("Điều hòa\Data.xlsx", sheet_name='Câu trả lời')
tl_train = pd.read_excel("Tủ lạnh\Data.xlsx", sheet_name='Câu trả lời')

# %%
from pyvi import ViTokenizer
import regex as re

uniChars = "àáảãạâầấẩẫậăằắẳẵặèéẻẽẹêềếểễệđìíỉĩịòóỏõọôồốổỗộơờớởỡợùúủũụưừứửữựỳýỷỹỵÀÁẢÃẠÂẦẤẨẪẬĂẰẮẲẴẶÈÉẺẼẸÊỀẾỂỄỆĐÌÍỈĨỊÒÓỎÕỌÔỒỐỔỖỘƠỜỚỞỠỢÙÚỦŨỤƯỪỨỬỮỰỲÝỶỸỴÂĂĐÔƠƯ"
unsignChars = "aaaaaaaaaaaaaaaaaeeeeeeeeeeediiiiiooooooooooooooooouuuuuuuuuuuyyyyyAAAAAAAAAAAAAAAAAEEEEEEEEEEEDIIIOOOOOOOOOOOOOOOOOOOUUUUUUUUUUUYYYYYAADOOU"
 
def loaddicchar():
    dic = {}
    char1252 = 'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ'.split(
        '|')
    charutf8 = "à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ".split(
        '|')
    for i in range(len(char1252)):
        dic[char1252[i]] = charutf8[i]
    return dic
 
 
dicchar = loaddicchar()
 
# Đưa toàn bộ dữ liệu qua hàm này để chuẩn hóa lại
def convert_unicode(txt):
    return re.sub(
        r'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ',
        lambda x: dicchar[x.group()], txt)

def text_preprocess(document):
    # chuẩn hóa unicode
    document = convert_unicode(document)
    # tách từ(từ đơn và từ ghép)
    document = ViTokenizer.tokenize(document)
    # đưa về chữ viết thường
    document = document.lower()
    #loại bỏ ký tự đặc biệt
    document = re.sub(r'[^\s\wáàảãạăắằẳẵặâấầẩẫậéèẻẽẹêếềểễệóòỏõọôốồổỗộơớờởỡợíìỉĩịúùủũụưứừửữựýỳỷỹỵđ_]',' ',document)
    # xóa khoảng trắng thừa
    document = re.sub(r'\s+', ' ', document).strip()
    return document

for i in range(len(dh_train['Triệu chứng'])):
    dh_train['Triệu chứng'][i] = text_preprocess(dh_train['Triệu chứng'][i])

for i in range(len(tl_train['Triệu chứng'])):
    tl_train['Triệu chứng'][i] = text_preprocess(tl_train['Triệu chứng'][i])

dh_train
# Out:
#                          Triệu chứng    Mã
# 0               điều hòa bình_thường  HD01
# 1    điều hòa không có hiện_tượng gì  HD01
# 2        điều hòa khống có vấn_đề gì  HD01
# 3     điều hòa hoạt_động bình_thường  HD01
# 4         điều hòa hoạt_động ổn_định  HD01
# ..                               ...   ...
# 255           tín_hiệu không ổn_định  TH03
# 256            tín_hiệu điều hòa_kém  TH03
# 257              tín_hiệu remote kém  TH03
# 258                     tín_hiệu kém  TH03
# 259                    tín_hiệu chậm  TH03
#
# [260 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score

#gán tập dữ liệu
dh_x_train = list(dh_train['Triệu chứng'])
dh_y_train = list(dh_train['Mã'])
tl_x_train = list(tl_train['Triệu chứng'])
tl_y_train = list(tl_train['Mã'])

dh_x_train, dh_y_train
# Out:
# (['điều hòa bình_thường',
#   'điều hòa không có hiện_tượng gì',
#   'điều hòa khống có vấn_đề gì',
#   'điều hòa hoạt_động bình_thường',
#   'điều hòa hoạt_động ổn_định',
#   'điều hòa chạy liên_tục',
#   'điều hòa chạy liên_tục nhưng không lạnh',
#   'điều hòa chạy liên_tục nhưng không thấy lạnh',
#   'điều hòa chạy không ngừng',
#   'điều hòa chạy liên_tục không ngừng',
#   'điều hòa hoạt_động liên_tục',
#   'điều hòa hoạt_động liên_tục nhưng không lạnh',
#   'điều hòa hoạt_động liên_tục nhưng không lạnh',
#   'điều hòa không tự ngắt',
#   'điều hòa hoạt_động không ngừng',
#   'điều hòa hoạt_động liên_tục không ngừng',
#   'điều hòa không tự ngắt khi đạt đến nhiệt_độ',
#   'điều hòa động_cơ bật tắt liên_tục',
#   'điều hòa bật tắt liên_tục',
#   'điều hòa liên_tục bật_tắt',
#   'điều hòa động_cơ liên_tục bật_tắt',
#   'điều hòa đông cơ bật tắt bất_thường',
#   'điều hòa tự_động tắt',
#   'điều hòa tự_động ngắt',
#   'điều hòa tự_động tắt sau 5 phút',
# ...

# %%
import joblib
from sklearn.feature_extraction.text import TfidfVectorizer
  
dh_vectorization = TfidfVectorizer()
tl_vectorization = TfidfVectorizer()

dh_x_train = dh_vectorization.fit_transform(dh_x_train)
tl_x_train = tl_vectorization.fit_transform(tl_x_train)

joblib.dump(dh_vectorization, open("Điều hòa/tfidf.pkl", "wb"))
joblib.dump(tl_vectorization, open("Tủ lạnh/tfidf.pkl", "wb"))
# x_train.data, x_test.data

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
dh_model = RandomForestClassifier()
dh_model.fit(dh_x_train, dh_y_train)

tl_model = RandomForestClassifier()
tl_model.fit(tl_x_train, tl_y_train)
# Out:
# RandomForestClassifier()

# %%
import joblib
joblib.dump(dh_model, 'Điều hòa/model.joblib')
joblib.dump(tl_model, 'Tủ lạnh/model.joblib')
# Out:
# ['Tủ lạnh/model.joblib']

# %%
df = pd.read_excel("Điều hòa\data.xlsx", sheet_name='Câu trả lời')
for i in range(len(df['Triệu chứng'])):
    df['Triệu chứng'][i] = text_preprocess(df['Triệu chứng'][i])
df = df.sample(n=50)
print(df['Mã'])
df = list(df['Triệu chứng'])

df = dh_vectorization.transform(df)
dh_model.predict(df)
# Out:
# 59     TT03
# 211    CN07
# 84     ND03
# 118    DB02
# 80     ND03
# 201    CN05
# 45     HD08
# 190    CN03
# 159    QN01
# 176    QN04
# 90     ND04
# 177    QN04
# 33     HD05
# 12     HD02
# 230     M02
# 63     TT03
# 135    QL02
# 88     ND04
# 92     ND04
# 119    DB02
# 104    ND05
# 34     HD06
# 55     TT02
# 141    QL03
# 207    CN06
# 129    DB04
# 128    DB04
# 66     TT04
# 232     M02
# 242    TH01
# 192    CN03
# 178    QN04
# 186    CN02
# 91     ND04
# 82     ND03
# 217    OD01
# 2      HD01
# 165    QN02
# 14     HD02
# 198    CN04
# 121    DB03
# 229     M01
# 244    TH01
# 254    TH03
# 167    QN02
# 113    DB02
# 200    CN05
# 48     HD08
# 195    CN04
# 71     ND01
# Name: Mã, dtype: object
# array(['TT03', 'CN07', 'ND03', 'DB02', 'ND03', 'CN05', 'HD08', 'CN03',
#        'ND01', 'QN04', 'ND04', 'QN04', 'HD05', 'HD02', 'M02', 'TT03',
#        'QL02', 'ND04', 'ND04', 'DB02', 'ND05', 'HD06', 'TT02', 'QL03',
# ...
